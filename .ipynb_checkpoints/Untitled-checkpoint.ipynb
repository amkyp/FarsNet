# %%
import networkx as nx
from pyvis.network import Network
import pandas as pd
import sqlite3
from farsnet import *

# class FarsGraph: 
#     def __init__(self):
#         df = pd.read_csv('farsnet/synset_relation.csv', delimiter=',')
#         self.G = nx.from_pandas_edgelist(df, source='synsetWords1', target='synsetWords2', edge_attr='type',
#                                          create_using=nx.MultiDiGraph())
class FarsGraph:
    def __init__(self):
        df = pd.read_csv('farsnet/synset_relation.csv', delimiter=',')
        df['synsetWords1'] = df['synsetWords1'].astype(str)
        df['synsetWords2'] = df['synsetWords2'].astype(str)
        self.G = nx.from_pandas_edgelist(df, source='synsetWords1', target='synsetWords2', edge_attr='type',
                                         create_using=nx.MultiDiGraph())

    def visualize(self):
        net = Network(notebook=True, width=1124, height=700)
        net.from_nx(self.G)
        net.show_buttons(filter_=['physics'])
        net.show('farsnet.html')

    def find_pred(self, node):
        return self.G.predecessors(',' + node)

    def find_relations(self, src, des):
        return self.G.get_edge_data(src, des)

    @staticmethod
    def denormalize(token):
        """ Unfortunately, some of FarsNet entries are not normalized so the input should be denormalized to have
        a better chance of string matching! """
        return token.replace("ی", "ي")

    @classmethod
    def get_synsets_by_word(cls, searchKeyword, style):
        searchKeyword = cls.denormalize(searchKeyword)
        if style == "LIKE":
            searchKeyword = "%" + searchKeyword + "%"
        elif style == 'START':
            searchKeyword = "" + searchKeyword + "%"
            style = "LIKE"
        elif style == 'END':
            searchKeyword = "%" + searchKeyword + ""
            style = "LIKE"
        else:
            style = '='
        
        conn = sqlite3.connect('farsnet3.0.db3')  # Replace with your actual database
        cursor = conn.cursor()
        
        query = f"""
            SELECT id, pos, semanticCategory, example, gloss, nofather, noMapping FROM synset
            WHERE synset.id IN (
                SELECT synset.id as synset_id
                FROM word
                INNER JOIN sense ON sense.word = word.id
                INNER JOIN synset ON sense.synset = synset.id
                LEFT OUTER JOIN value ON value.word = word.id
                WHERE word.search_value {style} '{searchKeyword}'
                OR value.search_value {style} '{searchKeyword}'
            )
            OR synset.id IN (
                SELECT sense.synset AS synset_id
                FROM sense
                INNER JOIN sense_relation ON sense.id = sense_relation.sense
                INNER JOIN sense AS sense_2 ON sense_2.id = sense_relation.sense2
                INNER JOIN word ON sense_2.word = word.id
                WHERE sense_relation.type = 'Refer-to'
                AND word.search_value {style} '{searchKeyword}'
            )
            OR synset.id IN (
                SELECT sense_2.synset AS synset_id
                FROM sense
                INNER JOIN sense_relation ON sense.id = sense_relation.sense
                INNER JOIN sense AS sense_2 ON sense_2.id = sense_relation.sense2
                INNER JOIN word ON sense.word = word.id
                WHERE sense_relation.type = 'Refer-to'
                AND word.search_value {style} '{searchKeyword}'
            )
        """
        
        cursor.execute(query)
        results = cursor.fetchall()
        conn.close()
        return results

    @staticmethod
    def get_synset_relation_by_id(synset_id):
        conn = sqlite3.connect('farsnet3.0.db3')  # Replace with your actual database
        query = f"""
            SELECT id, type, synsetWords1, synsetWords2, synset, synset2, reverse_type 
            FROM synset_relation 
            WHERE synset={synset_id} OR
            synset2={synset_id}
        """
        df = pd.read_sql_query(query, conn)
        conn.close()
        return df

    @staticmethod
    def get_all_synsets():
        conn = sqlite3.connect('farsnet3.0.db3')  # Replace with your actual database
        query = "SELECT id, pos, semanticCategory, example, gloss, nofather, noMapping FROM synset"
        df = pd.read_sql_query(query, conn)
        conn.close()
        return df

# # instantiate jupyter notebook to visualize the graph

            
# # Instantiate the class
# fars_graph = FarsGraph()

# # Visualize the graph
# fars_graph.visualize()

# # Find predecessors of a node
# predecessors = list(fars_graph.find_pred('some_node'))
# print(predecessors)

# # Find relations between two nodes
# relations = fars_graph.find_relations('node1', 'node2')
# print(relations)

# # Get synsets by word
# synsets = FarsGraph.get_synsets_by_word('word', 'LIKE')
# print(synsets)

# # Get synset relation by ID
# synset_relations = FarsGraph.get_synset_relation_by_id(12345)
# print(synset_relations)

# # Get all synsets
# all_synsets = FarsGraph.get_all_synsets()
# print(all_synsets)

# %%
import networkx as nx
from pyvis.network import Network
import pandas as pd
import sqlite3
from farsnet import *
import json

# class FarsGraph: 
#     def __init__(self):
#         df = pd.read_csv('farsnet/synset_relation.csv', delimiter=',')
#         self.G = nx.from_pandas_edgelist(df, source='synsetWords1', target='synsetWords2', edge_attr='type',
#                                          create_using=nx.MultiDiGraph())
class FarsGraph:
    def __init__(self):
        df = pd.read_csv('farsnet/synset_relation.csv', delimiter=',')
        df['synsetWords1'] = df['synsetWords1'].astype(str)
        df['synsetWords2'] = df['synsetWords2'].astype(str)
        self.G = nx.from_pandas_edgelist(df, source='synsetWords1', target='synsetWords2', edge_attr='type',
                                         create_using=nx.MultiDiGraph())

    def visualize(self):
        net = Network(notebook=True, width=1124, height=700)
        net.from_nx(self.G)
        net.show_buttons(filter_=['physics'])
        net.show('farsnet.html')

    def find_pred(self, node):
        return self.G.predecessors(',' + node)

    def find_relations(self, src, des):
        return self.G.get_edge_data(src, des)

    @staticmethod
    def denormalize(token):
        """ Unfortunately, some of FarsNet entries are not normalized so the input should be denormalized to have
        a better chance of string matching! """
        return token.replace("ی", "ي")

    @classmethod
    def get_synsets_by_word(cls, searchKeyword, style):
        searchKeyword = cls.denormalize(searchKeyword)
        if style == "LIKE":
            searchKeyword = "%" + searchKeyword + "%"
        elif style == 'START':
            searchKeyword = "" + searchKeyword + "%"
            style = "LIKE"
        elif style == 'END':
            searchKeyword = "%" + searchKeyword + ""
            style = "LIKE"
        else:
            style = '='
        
        conn = sqlite3.connect('farsnet3.0.db3')  # Replace with your actual database
        cursor = conn.cursor()
        
        query = f"""
            SELECT id, pos, semanticCategory, example, gloss, nofather, noMapping FROM synset
            WHERE synset.id IN (
                SELECT synset.id as synset_id
                FROM word
                INNER JOIN sense ON sense.word = word.id
                INNER JOIN synset ON sense.synset = synset.id
                LEFT OUTER JOIN value ON value.word = word.id
                WHERE word.search_value {style} '{searchKeyword}'
                OR value.search_value {style} '{searchKeyword}'
            )
            OR synset.id IN (
                SELECT sense.synset AS synset_id
                FROM sense
                INNER JOIN sense_relation ON sense.id = sense_relation.sense
                INNER JOIN sense AS sense_2 ON sense_2.id = sense_relation.sense2
                INNER JOIN word ON sense_2.word = word.id
                WHERE sense_relation.type = 'Refer-to'
                AND word.search_value {style} '{searchKeyword}'
            )
            OR synset.id IN (
                SELECT sense_2.synset AS synset_id
                FROM sense
                INNER JOIN sense_relation ON sense.id = sense_relation.sense
                INNER JOIN sense AS sense_2 ON sense_2.id = sense_relation.sense2
                INNER JOIN word ON sense.word = word.id
                WHERE sense_relation.type = 'Refer-to'
                AND word.search_value {style} '{searchKeyword}'
            )
        """
        
        cursor.execute(query)
        results = cursor.fetchall()
        conn.close()
        return results

    @staticmethod
    def get_synset_relation_by_id(synset_id):
        conn = sqlite3.connect('farsnet3.0.db3')  # Replace with your actual database
        query = f"""
            SELECT id, type, synsetWords1, synsetWords2, synset, synset2, reverse_type 
            FROM synset_relation 
            WHERE synset={synset_id} OR
            synset2={synset_id}
        """
        df = pd.read_sql_query(query, conn)
        conn.close()
        return df

    @staticmethod
    def get_all_synsets():
        conn = sqlite3.connect('farsnet3.0.db3')  # Replace with your actual database
        query = "SELECT id, pos, semanticCategory, example, gloss, nofather, noMapping FROM synset"
        df = pd.read_sql_query(query, conn)
        conn.close()
        return df

# 1. Find All Senses of a Word with Examples and All Related Information
    @classmethod
    def get_all_senses(cls, word):
        word = cls.denormalize(word)
        conn = sqlite3.connect('farsnet3.0.db3')
        query = f"""
            SELECT sense.id, word.search_value, sense.synset, synset.pos, synset.semanticCategory, synset.example, synset.gloss
            FROM word
            JOIN sense ON word.id = sense.word
            JOIN synset ON sense.synset = synset.id
            WHERE word.search_value = '{word}'
        """
        df = pd.read_sql_query(query, conn)
        conn.close()
        return df
# 2. Identify Synsets with Multiple Senses
    @staticmethod
    def synsets_with_multiple_senses():
        conn = sqlite3.connect('farsnet3.0.db3')
        query = """
            SELECT synset, COUNT(*) as sense_count
            FROM sense
            GROUP BY synset
            HAVING sense_count > 1
        """
        df = pd.read_sql_query(query, conn)
        conn.close()
        return df
# 3. Retrieve Words with Their Most Common Sense
    # @staticmethod
    # def words_with_most_common_sense():
    #     conn = sqlite3.connect('farsnet3.0.db3')
    #     query = """
    #         SELECT word.search_value, sense.synset, COUNT(sense.synset) as frequency
    #         FROM word
    #         JOIN sense ON word.id = sense.word
    #         GROUP BY word.search_value, sense.synset
    #         ORDER BY word.search_value, frequency DESC
    #     """
    #     df = pd.read_sql_query(query, conn)
    #     conn.close()
    #     return df.groupby('word').first().reset_index()
    @staticmethod
    def words_with_most_common_sense():
        conn = sqlite3.connect('farsnet3.0.db3')
        query = """
            SELECT word.search_value as word, sense.synset, COUNT(sense.synset) as frequency
            FROM word
            JOIN sense ON word.id = sense.word
            GROUP BY word.search_value, sense.synset
            ORDER BY word.search_value, frequency DESC
        """
        df = pd.read_sql_query(query, conn)
        conn.close()
        # return df.groupby('word').first().reset_index()
        # 
        return df.groupby('word').apply(lambda x: x.nlargest(1, 'frequency')).reset_index(drop=True)

    
# 4. List Synsets and Their Corresponding Lexicon Information
    @staticmethod
    def synsets_with_lexicon_info():
        conn = sqlite3.connect('farsnet3.0.db3')
        query = """
            SELECT synset.id, synset.pos, synset.semanticCategory, synset.example, synset.gloss, word.search_value
            FROM synset
            JOIN sense ON synset.id = sense.synset
            JOIN word ON sense.word = word.id
        """
        df = pd.read_sql_query(query, conn)
        conn.close()
        return df
# 5. Extract Senses and Their Synsets for a Particular Part of Speech
    @staticmethod
    def senses_by_pos(pos):
        conn = sqlite3.connect('farsnet3.0.db3')
        query = f"""
            SELECT sense.id, sense.synset, synset.pos, word.search_value
            FROM sense
            JOIN synset ON sense.synset = synset.id
            JOIN word ON sense.word = word.id
            WHERE synset.pos = '{pos}'
        """
        df = pd.read_sql_query(query, conn)
        conn.close()
        return df
# 6. Determine the Distribution of Senses Across Different Parts of Speech
    @staticmethod
    def senses_distribution():
        conn = sqlite3.connect('farsnet3.0.db3')
        query = """
            SELECT synset.pos, COUNT(sense.id) as sense_count
            FROM sense
            JOIN synset ON sense.synset = synset.id
            GROUP BY synset.pos
        """
        df = pd.read_sql_query(query, conn)
        conn.close()
        return df
# 7. Identify Unique Senses for a Given Semantic Category
    @staticmethod
    def unique_senses_by_semantic_category(category):
        conn = sqlite3.connect('farsnet3.0.db3')
        query = f"""
            SELECT DISTINCT sense.id, sense.synset, word.search_value
            FROM sense
            JOIN synset ON sense.synset = synset.id
            JOIN word ON sense.word = word.id
            WHERE synset.semanticCategory = '{category}'
        """
        df = pd.read_sql_query(query, conn)
        conn.close()
        return df
# 8. Retrieve Examples for Synsets with a Specific Gloss Pattern
    @staticmethod
    def synsets_with_gloss_pattern(pattern):
        conn = sqlite3.connect('farsnet3.0.db3')
        query = f"""
            SELECT synset.id, synset.example, synset.gloss
            FROM synset
            WHERE synset.gloss LIKE '%{pattern}%'
        """
        df = pd.read_sql_query(query, conn)
        conn.close()
        return df
# 9. Find Synsets with No Direct Mapping and Their Glosses
    @staticmethod
    def synsets_with_no_mapping():
        conn = sqlite3.connect('farsnet3.0.db3')
        query = """
            SELECT id, gloss
            FROM synset
            WHERE noMapping = 1
        """
        df = pd.read_sql_query(query, conn)
        conn.close()
        return df

    # @classmethod
    # def get_all_synsets_for_all_words(cls):
    #     conn = sqlite3.connect('farsnet3.0.db3')
    #     query = """
    #         SELECT word.search_value as word, sense.id as sense_id, sense.synset, synset.pos, synset.semanticCategory, 
    #                synset.example, synset.gloss, word.pos as word_pos, word.avaInfo, word.defaultValue
    #         FROM word
    #         JOIN sense ON word.id = sense.word
    #         JOIN synset ON sense.synset = synset.id
    #     """
    #     df = pd.read_sql_query(query, conn)
    #     conn.close()

    #     # Group by word and create a list of synsets for each word
    #     result = {}
    #     for index, row in df.iterrows():
    #         word = row['word']
    #         sense_info = {
    #             'sense_id': row['sense_id'],
    #             'synset_id': row['synset'],
    #             'pos': row['pos'],
    #             'semanticCategory': row['semanticCategory'],
    #             'example': row['example'],
    #             'gloss': row['gloss'],
    #             'word_pos': row['word_pos'],
    #             'avaInfo': row['avaInfo'],
    #             'defaultValue': row['defaultValue']
    #         }
    #         if word not in result:
    #             result[word] = []
    #         result[word].append(sense_info)

    #     # Save the result as a JSON file
    #     with open('all_synsets_for_all_words.json', 'w', encoding='utf-8') as f:
    #         json.dump(result, f, ensure_ascii=False, indent=4)

    #     return result

    @staticmethod
    def get_all_senses_for_all_words():
        conn = sqlite3.connect('farsnet3.0.db3')
        query = """
            SELECT sense.id, word.search_value, sense.synset, synset.pos, synset.semanticCategory, 
                   synset.example, synset.gloss
            FROM word
            JOIN sense ON word.id = sense.word
            JOIN synset ON sense.synset = synset.id
            ORDER BY word.search_value
        """
        df = pd.read_sql_query(query, conn)
        conn.close()

        # Save the result as a CSV file
        df.to_csv('all_senses_for_all_words.csv', index=False, encoding='utf-8-sig')
        
        return df

    @classmethod
    def get_all_senses_for_words(cls, words_file):
        # Load words from CSV file
        words_df = pd.read_csv(words_file)
        words = words_df['word'].tolist()

        conn = sqlite3.connect('farsnet3.0.db3')
        result = {}

        for word in words:
            word_denormalized = cls.denormalize(word)
            query = f"""
                SELECT sense.id, word.search_value, sense.synset, synset.pos, synset.semanticCategory, 
                       synset.example, synset.gloss
                FROM word
                JOIN sense ON word.id = sense.word
                JOIN synset ON sense.synset = synset.id
                WHERE word.search_value = '{word_denormalized}'
            """
            df = pd.read_sql_query(query, conn)
            
            # Process the DataFrame and construct the desired JSON structure
            senses = []
            for _, row in df.iterrows():
                sense_info = {
                    "meaning": row['gloss'],
                    "example": row['example'],
                    "pos": row['pos'],
                    "semantic_category": row['semanticCategory'],
                    "sense_id": row['id'],
                    "synset_id": row['synset'],
                
                }
                senses.append(sense_info)
            
            result[word] = senses

        conn.close()

        # Save the result as a JSON file
        with open('senses_for_words.json', 'w', encoding='utf-8') as f:
            json.dump(result, f, ensure_ascii=False, indent=4)

        return result

# %%
# Instantiate the class
fars_graph = FarsGraph()

# %%
# Visualize the graph
fars_graph.visualize()
# Out:
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
# farsnet.html

# %%
# Find predecessors of a node
from pprint import pprint
pprint(list(fars_graph.find_pred('گذشته')))
# Out:
# [',تجربه',
#  ',سابقه,پس\u200c\u200cزمينه,پيشينه',
#  ',غيرجاري',
#  ',پارسال,پار,پارينه',
#  ',پريروز',
#  ',پريشب',
#  ',پيشتر,قبلاً,سابقاً,پيشاپيش',
#  ',پس\u200cپريشب,پيش\u200cپريشب',
#  ',پس\u200cپريروز,پيش\u200cپريروز']

# %%
# Find relations between two nodes
print(fars_graph.find_relations('گرم', 'سرد'))
# Out:
# None

# %%
# Get synsets by word
pprint(fars_graph.get_synsets_by_word('خوب', 'LIKE'))
# Out:
# [(131,
#   'Adjective',
#   'material',
#   '--نامعلوم--:جنس خوبي دارد * --ازخودم--:يک غذاي درست\u200cودرمان خورديم *',
#   '--نامعلوم--:ويژگي آن\u200cچه رضايت\u200cبخش و مطلوب است *',
#   0,
#   0),
#  (139,
#   'Adjective',
#   'material',
#   '--نامعلوم--:دارو نافع بود و بيمار خوب شد *',
#   '--نامعلوم--:ويژگي آن\u200cچه  فايده دارد *',
#   0,
#   0),
#  (7866,
#   'Verb',
#   'consumption',
#   '--نامعلوم--:به پدر و مادر خود نيکي کنيد. تا جايي که مي\u200cتواني احسان و '
#   'نيکوکاري کن. *',
#   '--نامعلوم--:کار خير انجام دادن *',
#   0,
#   0),
#  (8042,
#   'Verb',
#   'communication',
#   '--نامعلوم--:بيخودي قضيه را بزرگ مي کرد، من از همه ماجرا خبر داشتم. *',
#   '--نامعلوم--:مهم و يا بزرگ جلوه دادن کسي يا چيزي *',
#   0,
#   0),
#  (8091,
#   'Verb',
#   'change',
#   '--نامعلوم--:داروهايت را که سر وقت بخوري بهتر مي شوي. *',
#   '--نامعلوم--:از حالت مريضي در آمدن *',
#   0,
#   0),
#  (8495,
#   'Verb',
#   'body',
#   '--نامعلوم--:اگر حالم خوب شود حتماً به زيارت آقا مي روم. * دهخدا:سرش برتافتم '
#   'تا عافيت يافت/سر از من لاجرم بدبخت برتافت. *',
#   '--نامعلوم--:از مريضي رها شدن *',
#   0,
#   0),
#  (8536,
#   'Verb',
#   'body',
#   '--نامعلوم--:اگر مي شد اين بيماري را درمان کرد که ديگه من غصه نداشتم. *',
#   '--نامعلوم--:کسي را از بيماري رهاندن *',
#   1,
#   0),
#  (10395,
#   'Noun',
#   'ACT',
#   '--نامعلوم--:توجه او به بچه\u200cها جاي تقدير دارد. *',
#   '--نامعلوم--:رفتار محبت\u200cآميز و از سر دوستي را گويند. *',
#   0,
#   0),
#  (11176,
#   'Noun',
#   'ATTRIBUTE',
#   '--نامعلوم--:جمال يک جنبه\u200cي ظاهري دارد و يک جنبه ي دروني. *',
#   '--نامعلوم--:ويژگي\u200cهايي که در حواس ما ايجاد لذت مي نمايد.  *',
#   0,
#   0),
#  (11244,
#   'Noun',
#   'ATTRIBUTE',
#   '--نامعلوم--:حسن و جنبۀ مثبت چنين کارهايي بسيار زياد است *',
#   '--نامعلوم--:هر کيفيت پسنديده و مطلوب، خوبي، نيکويي، زيبايي، جمال و فايده را '
#   'گويند. *',
#   0,
#   0),
#  (12147,
#   'Noun',
#   'PLANT',
#   'ريشه ي گياه را از خاک در آورد',
#   'يکي از اندامهاي  گياه که معمولاً زير زميني است و کار آن جذب آب و مواد مغذي '
#   ', حفظ و پايداري گياه و گاهي ذخيره ي مواد مغذي است',
#   0,
#   0),
#  (12412,
#   'Noun',
#   'STATE',
#   '--نامعلوم--:خوشي و خوشنودي او ناشي از موفقيتش در امتحان است. *',
#   '--نامعلوم--:حالت عاطفي شادبودن را گويند. *',
#   0,
#   0),
#  (14560,
#   'Noun',
#   'ATTRIBUTE',
#   '--نامعلوم--:خوبي اين اجناس به اثبات رسيده است. *',
#   '--نامعلوم--:داراي کيفيت مطلوب بودن را گويند. *',
#   0,
#   0),
#  (14626,
#   'Noun',
#   'ATTRIBUTE',
#   '--نامعلوم--:لطف او شامل حال همه شد *',
#   '--نامعلوم--:نيکي و مهرباني نمودن به ديگران را گويند. *',
#   0,
#   0),
#  (14894,
#   'Noun',
#   'ATTRIBUTE',
#   '--نامعلوم--:اميدوارم در زندگي خير هميشه يار و ياورت باشد *',
#   '--نامعلوم--:آنچه موجب موفقيت و سعادت باشد *',
#   0,
#   0),
#  (16423,
#   'Verb',
#   'body',
#   'او سالم و سرحال بود.',
#   'نداشتن بيماري جسمي يا روحي',
#   0,
#   0),
#  (16464,
#   'Verb',
#   'stative',
#   '--نامعلوم--:اين زمان براي من مناسب است. *',
#   '--نامعلوم--:مورد قبول و توافق بودن *',
#   0,
#   0),
#  (17719,
#   'Noun',
#   'ATTRIBUTE',
#   '--نامعلوم--:درستکاري و صداقت موجب جلب اطمينان ديگران مي\u200cشود. *',
#   '--نامعلوم--:رفتار درست و دور از خيانت، دروغ و نيرنگ را گويند. *',
#   0,
#   0),
#  (17799,
#   'Adjective',
#   'conceptual',
#   '--نامعلوم--:در خوابش فرشته\u200cاي زيبارو با او هم\u200cکلام شد. * '
#   '--ازخودم--:دوباره آن دختر زيبا را ديد *',
#   '--نامعلوم--:ويژگي آن\u200cکه چهره\u200cاي جذاب و دوست\u200cداشتني دارد.    '
#   '*',
#   0,
#   0),
#  (19279,
#   'Noun',
#   'ATTRIBUTE',
#   '--نامعلوم--:من اين حرف را از روي خيرخواهي و علاقه به شما مي\u200cزنم. *',
#   '--نامعلوم--:عادت يا گرايش به انجام دادن کارهايي به سود ديگري يا ديگران را '
#   'گويند. *',
#   0,
#   0),
#  (19694,
#   'Noun',
#   'ATTRIBUTE',
#   '--نامعلوم--:خوشگلي او به خاطر اين است که والدينش هم خوشگلند.  * '
#   '--نامعلوم--: خوشگلي و زيبايي او به واسطه چشمان درشت و بيني ريزش است. *',
#   '--نامعلوم--:وضع و کيفيت خوشگل بودن را گويند. *',
#   0,
#   0),
#  (21826,
#   'Adverb',
#   'کيفيت',
#   '--نامعلوم--:قهرمان ژيمناستيک به\u200cزيبايي حرکاتش را انجام داد. * '
#   '--نامعلوم--:خواهرم قرآن را قشنگ مي\u200cخواند. * --نامعلوم--:دوست داشتم گوش '
#   'بدهم چون قشنگ حرف مي زد *',
#   '--نامعلوم--:به گونه\u200cاي مطلوب و دلپذير *',
#   0,
#   0),
#  (26754,
#   'Adverb',
#   'کيفيت',
#   'خوب رانندگي مي کند*در بازي ديروز رضايت بخش کار نکردند*هميشه وظايفش را به '
#   'خوبي انجام مي دهد',
#   'به گونه اي مطلوب و قابل قبول',
#   0,
#   0),
#  (26978,
#   'Adjective',
#   'behavior',
#   '--نامعلوم--:اعمال نيک *',
#   '--نامعلوم--:داراي ارزش معنوي *',
#   0,
#   0),
#  (27084,
#   'Adjective',
#   'behavior',
#   '--نامعلوم--:جوان سربه\u200cراه * --نامعلوم--:فرزند صالح * --نامعلوم--:تاجر '
#   'درستکار *',
#   '--نامعلوم--:ويژگي آن\u200cکه راه درست را در زندگي مي\u200cپيمايد و از '
#   'کارهاي نادرست پرهيز مي\u200cکند *',
#   0,
#   0),
#  (27203,
#   'Adjective',
#   'relation',
#   'اوضاع مساعد اقتصادي * شرايط مساعد جوي* حال و احوال خوب * شرايط مطلوب*زمان '
#   'مناسب',
#   'موافق و سازگار، بر وفق مراد',
#   0,
#   0),
#  (28498,
#   'Verb',
#   'social',
#   '--نامعلوم--:هر کس با ديگران خوش\u200cرفتاري کند، زندگي\u200cاش گوارا '
#   'مي\u200cگردد. *',
#   '--نامعلوم--:برخورد مناسب و خوبي با کسي داشتن *',
#   0,
#   0),
#  (29691,
#   'Adjective',
#   'social',
#   '--نامعلوم--:فروشنده خوش\u200cذات پول جنس را از مرد نيازمند نگرفت *',
#   '--نامعلوم--:ويژگي آن\u200cکه ذات و سرشت او خوب است *',
#   0,
#   0),
#  (34371,
#   'Verb',
#   'cognition',
#   'گفت فال شب يلداي من خوب آمده است، نگران نباش.',
#   'چيزي را خوب و پسنديده پنداشتن',
#   0,
#   0),
#  (34443,
#   'Adjective',
#   'quantity',
#   'درختان پرشاخ\u200cوبرگ',
#   'ويژگي گياهي که شاخه و برگ بسيار دارد',
#   0,
#   0),
#  (35108,
#   'Adjective',
#   'relation',
#   '--نامعلوم--:مرض قابل\u200cعلاج * وب:وقتي مي\u200cگوييم سرطان\u200cهاي پوست '
#   'شفاپذير هستند منظور سرطان\u200cهاي غيرملانوم هستند که بسيار شايع هستند\n'
#   ' *',
#   '--نامعلوم--:ويژگي بيماري\u200cاي که درمان دارد *',
#   0,
#   0),
#  (36857,
#   'Adjective',
#   'body',
#   'دلبر ناز نازک\u200cاندام*يار شکرلب گل\u200cاندام',
#   'ويژگي آن\u200cکه اندام زيبايي دارد (ادبي)',
#   0,
#   0),
#  (38887,
#   'Verb',
#   'stative',
#   'وب:او به پليس گفت که همسرش زيبا بوده است. *',
#   '--ساير--:داراي چهره دلپسند و چشم نواز بودن *',
#   0,
#   0),
#  (39810,
#   'Adverb',
#   'کيفيت',
#   '--ازخودم--:اين طرح از اصل اشتباه بود * --ازخودم--:اين آدم از بيخ نفهم است * '
#   '--ازخودم--:فيلمنامه از اساس بايد تغيير کند *',
#   '--ازخودم--:به طور ريشه\u200cاي و کامل *',
#   0,
#   0),
#  (41263,
#   'Verb',
#   'stative',
#   'وب:پدرش اهل مطالعه و در عين حال مردي تندخو بود. * --ازخودم--:توپ\u200cاش از '
#   'دست تو پر است، فعلاً دوروبرش آفتابي نشو. * --ازخودم--:امروز که حرصي بود از '
#   'زمين و زمان و از بخت بدش گله مي\u200cکرد. *',
#   '--ساير--:داراي خلق\u200cوخوي خشونت\u200cبار بودن * --ازخودم--:از موضوعي '
#   'شديداً ناراحت و شاکي بودن که عموماً با رفتاري تند همراه مي\u200cشود *',
#   0,
#   1),
#  (41332,
#   'Noun',
#   'PLANT',
#   '--ازخودم--:شاخ\u200cوبرگ اين درختان و گياهان نيازمند هرس کردن است. * '
#   '--ساير--:در طول زمان پرورش، حداقل دوبار به وسيله قارچ کش شاخ و برگ '
#   'نرگس\u200cها را سم\u200cپاشي کنيد. \n'
#   ' *',
#   'سخن:شاخه و برگ درخت *',
#   0,
#   0),
#  (41333,
#   'Noun',
#   'COMMUNICATION',
#   '--ازخودم--:از شاخ و برگ ماجرا بزن و اصل داستان را تعريف کن. *',
#   'سخن:توضيحات اضافي در بيان چيزي، زوائد و جزئيات *',
#   0,
#   1),
#  (41554,
#   'Verb',
#   'stative',
#   '--ازخودم--:مادربزرگ به معناي واقعي آزاده بود. *',
#   'سخن:عاري از تعصب و اخلاق ناپسند بودن *',
#   0,
#   1),
#  (42010,
#   'Noun',
#   'ATTRIBUTE',
#   'سخن:پسنديدگي اخلاق او بر همه روشن شده\u200cاست. *',
#   '--ازخودم--:خوب و پسنديده بودن *',
#   0,
#   0),
#  (42350,
#   'Verb',
#   'stative',
#   '--ازخودم--:اگرچه بدخو بود، اما همه او را به سخاوت و صداقت مي\u200cشناختند. '
#   '*',
#   '--ازخودم--:داراي سلوک بد با ديگران بودن *',
#   0,
#   1),
#  (42449,
#   'Verb',
#   'stative',
#   '--ازخودم--:اگر مي توانستي اين کتاب را بخواني خوب بود. *',
#   '--ازخودم--:پسنديده، سودمند، يا مرغوب بودن  *',
#   0,
#   1),
#  (42450,
#   'Verb',
#   'change',
#   '--ازخودم--:بايد کمي بهتر باغچه برسم تا وضعيتش خوب شود. *',
#   '--ازخودم--:پسنديده، سودمند، يا مرغوب شدن *',
#   0,
#   1),
#  (42928,
#   'Noun',
#   'SUBSTANCE',
#   'ويکي پديا:در افراد سالم ميزان HDL خون در زنان بهتر است بيشتر از 50 ميلي '
#   '\u200fگرم در صد ميلي \u200fليتر خون و در مردان بيشتر از 45 باشد. *',
#   'وب:يکي از ملکول\u200f هاي چربي خون از نوع ليپوپروتئين است که قسمت اعظم آن '
#   'پروتئين (50 درصد) و قسمت کمتر آن را کلسترول و تري \u200fگلسيريد تشکيل مي '
#   '\u200fدهد و کار عمده آن انتقال کلسترول از بافت \u200fها و هدايت آن به سمت '
#   'کبد است. *',
#   0,
#   0),
#  (44018,
#   'Noun',
#   'ACT',
#   '--ازخودم--:هميشه به خوب\u200cخوري و ورزش اهميت مي\u200cدهد و براي همين تني '
#   'سالم دارد. *',
#   'سخن:خوردن چيزهاي سالم و مفيد *',
#   0,
#   1),
#  (44180,
#   'Verb',
#   'stative',
#   'وب:مومن هم در باطن، مسرور و هم در چهره و رفتار گشاده\u200cرو است *',
#   '--ساير--:داشتن چهره\u200cاي خندان و خوش در ملاقات با ديگران  *',
#   0,
#   1),
#  (47554,
#   'Adjective',
#   'behavior',
#   '--ازخودم--:از انسان\u200cهاي نيک روزگار بود *',
#   '--ازخودم--:ويژگي آن\u200cکه از لحاظ اخلاقي و شخصيتي مورد تأييد است *',
#   0,
#   0),
#  (48745,
#   'Adverb',
#   'کيفيت',
#   'وب:او سعي مي\u200cکند خودش را متقاعد کند که اتفاقي نيافتاده و قرار است با '
#   'ايوان سال\u200cهاي سال به خوبي و خوشي زندگي کنند  *',
#   'سخن:همراه با آسايش و شادي\n *',
#   0,
#   0)]

# %%
# Get synset relations by id
print(fars_graph.get_synset_relation_by_id(1))
# Out:
#        id        type                 synsetWords1  \
# 0    5286     Antonym                 داخلي, توکار
# 1  143698  Related-to  بيروني, خارجي, روکار, بروني
# 2  143699  Related-to  بيروني, خارجي, روکار, بروني
# 3  143702  Related-to  بيروني, خارجي, روکار, بروني
#
#                   synsetWords2  synset  synset2 reverse_type
# 0  بيروني, خارجي, روکار, بروني       2        1      Antonym
# 1     نماي ساختمان, نما, روکار       1    29920   Related-to
# 2                      سيم‌کشي       1    27736   Related-to
# 3     پريز, کليد برق, پريز برق       1    35438   Related-to

# %%
# Get all synsets
print(fars_graph.get_all_synsets())
# Out:
#           id        pos semanticCategory  \
# 0          1  Adjective          spatial
# 1          2  Adjective          spatial
# 2          3  Adjective       conceptual
# 3          4  Adjective       conceptual
# 4          5  Adjective       conceptual
# ...      ...        ...              ...
# 42248  51718       Noun          PROCESS
# 42249  51719       Verb             body
# 42250  51720       Verb         creation
# 42251  51721       Noun         LOCATION
# 42252  51722       Noun         LOCATION
#
#                                                  example  \
# 0                             --ازخودم--:سيم‌کشي روکار *
# 1      --نامعلوم--:سيم‌کشي توکار * وب: سيستم لوله‌کشي...
# 2      آب خنک هميشه مي چسبد*اينجا هواي خنک و دلچسبي دارد
# 3                                آهن داغ*زغال هاي گداخته
# 4      --نامعلوم--:انسان معمولا با دوستان صميمي درددل...
# ...                                                  ...
# 42248  --ازخودم--:براي رفع ابهام معنايي واژگان متن مو...
# 42249  سخن:از مسافرت که برگشتم، خيلي تکيده شده بودم. ...
# 42250             سخن:در نور چراغ قوه دارم قلم مي‌زنم. *
# 42251  ويکي پديا:آذربايجان غربي و شهرستان اروميه قطب ...
# 42252  ويکي پديا:نيک شهر از نظر جمعيتي در حد متوسط قر...
#
#                                                    gloss  nofather  noMapping
# 0         --نامعلوم--:مربوط به سطح بيروني يا رويي چيزي *       0.0        0.0
# 1          --نامعلوم--:مربوط به داخل يا سطح زيرين چيزي *       0.0        0.0
# 2                             داراي سردي ملايم و خوشايند       0.0        0.0
# 3                                      داراي گرماي سوزان       0.0        0.0
# 4              --نامعلوم--:داراي رابطه نزديک و صميمانه *       0.0        0.0
# ...                                                  ...       ...        ...
# 42248  --ازخودم--:ابهام زدايي از واژگان مبهم و داراي ...       0.0        1.0
# 42249               سخن:خوردن مواد مقوي براي تقويت شدن *       0.0        1.0
# 42250                          سخن:نوشتن يا نقاشي کردن *       0.0        1.0
# 42251  --ازخودم--:يکي از شهرستان‌هاي استان آذربايجان ...       0.0        1.0
# 42252  ويکي پديا:نيک‌شَهر يکي از شهرهاي استان سيستان ...       0.0        1.0
#
# [42253 rows x 7 columns]

# %%
# # Instantiate the class
# fars_graph = FarsGraph()

# # Visualize the graph
# fars_graph.visualize()

# # Find predecessors of a node
# print(fars_graph.find_pred('سگ'))

# # Find relations between two nodes
# print(fars_graph.find_relations('سگ', 'گربه'))

# # Get synsets by word
# print(fars_graph.get_synsets_by_word('سگ', 'LIKE'))

# # Get synset relations by id
# print(fars_graph.get_synset_relation_by_id(1))

# # Get all synsets
# print(fars_graph.get_all_synsets())

# # Denormalize a token
# print(fars_graph.denormalize('سگ'))


#######################################################
# predecessors = list(fars_graph.find_pred('some_node'))
# print(predecessors)

# # Find relations between two nodes
# relations = fars_graph.find_relations('node1', 'node2')
# print(relations)

# # Get synsets by word
# synsets = FarsGraph.get_synsets_by_word('word', 'LIKE')
# print(synsets)

# # Get synset relation by ID
# synset_relations = FarsGraph.get_synset_relation_by_id(12345)
# print(synset_relations)

# # Get all synsets
# all_synsets = FarsGraph.get_all_synsets()
# print(all_synsets)

# %%
# # Instantiate the class
# fars_graph = FarsGraph()

# %%
import sqlite3

def inspect_schema():
    conn = sqlite3.connect('farsnet3.0.db3')
    cursor = conn.cursor()

    # Inspect word table
    cursor.execute("PRAGMA table_info(word)")
    word_schema = cursor.fetchall()

    # Inspect sense table
    cursor.execute("PRAGMA table_info(sense)")
    sense_schema = cursor.fetchall()

    # Inspect synset table
    cursor.execute("PRAGMA table_info(synset)")
    synset_schema = cursor.fetchall()

    conn.close()

    return word_schema, sense_schema, synset_schema

word_schema, sense_schema, synset_schema = inspect_schema()

print("Word Table Schema:", word_schema)
print("Sense Table Schema:", sense_schema)
print("Synset Table Schema:", synset_schema)
# Out:
# Word Table Schema: [(0, 'id', 'INTEGER', 1, None, 1), (1, 'pos', 'TEXT', 1, 'NULL', 0), (2, 'avaInfo', 'TEXT', 1, 'NULL', 0), (3, 'defaultValue', 'TEXT', 1, 'NULL', 0), (4, 'search_value', 'TEXT', 1, 'NULL', 0)]
# Sense Table Schema: [(0, 'id', 'INTEGER', 1, None, 1), (1, 'seqId', 'TEXT', 1, 'NULL', 0), (2, 'value', 'TEXT', 1, 'NULL', 0), (3, 'word', 'INTEGER', 1, 'NULL', 0), (4, 'vtansivity', 'TEXT', 0, 'NULL', 0), (5, 'vactivity', 'TEXT', 0, 'NULL', 0), (6, 'vtype', 'TEXT', 0, 'NULL', 0), (7, 'synset', 'INTEGER', 0, 'NULL', 0), (8, 'vpastStem', 'TEXT', 0, 'NULL', 0), (9, 'vpresentStem', 'TEXT', 0, 'NULL', 0), (10, 'category', 'TEXT', 0, 'NULL', 0), (11, 'goupOrMokassar', 'TEXT', 0, 'NULL', 0), (12, 'nmofradGr', 'TEXT', 0, 'NULL', 0), (13, 'countableOrNotCountable', 'TEXT', 0, 'NULL', 0), (14, 'esmeZamir', 'TEXT', 0, 'NULL', 0), (15, 'adad', 'TEXT', 0, 'NULL', 0), (16, 'adverb_type_1', 'TEXT', 0, 'NULL', 0), (17, 'adverb_type_2', 'TEXT', 0, 'NULL', 0), (18, 'adj_pishin_vijegi', 'TEXT', 0, 'NULL', 0), (19, 'adj_type', 'TEXT', 0, 'NULL', 0), (20, 'noe_khas', 'TEXT', 0, 'NULL', 0), (21, 'nounType', 'TEXT', 0, 'NULL', 0), (22, 'adj_type_sademorakkab', 'TEXT', 0, 'NULL', 0), (23, 'vIssababi', 'INTEGER', 0, 'NULL', 0), (24, 'vIsIdiom', 'INTEGER', 0, 'NULL', 0), (25, 'vGozaraType', 'TEXT', 0, 'NULL', 0), (26, 'kootah_nevesht', 'INTEGER', 0, 'NULL', 0), (27, 'mohavere', 'INTEGER', 0, 'NULL', 0)]
# Synset Table Schema: [(0, 'id', 'INTEGER', 1, None, 1), (1, 'semanticCategory', 'TEXT', 1, 'NULL', 0), (2, 'example', 'TEXT', 1, 'NULL', 0), (3, 'gloss', 'TEXT', 1, 'NULL', 0), (4, 'pos', 'TEXT', 1, 'NULL', 0), (5, 'nofather', 'INTEGER', 0, 'NULL', 0), (6, 'noMapping', 'INTEGER', 0, 'NULL', 0)]

# %%
# Find all senses of a word with examples and related information
all_senses = fars_graph.get_all_senses('شیر')
display(all_senses)
# Out:
#         id search_value  synset   pos semanticCategory  \
# 0    32617          شير   14005  Noun             BODY
# 1    32618          شير   14014  Noun         LOCATION
# 2    32619          شير   14012  Noun            GROUP
# 3    32620          شير   14006  Noun             FOOD
# 4    32621          شير   14007  Noun         ARTIFACT
# 5    32622          شير   14013  Noun         ARTIFACT
# 6    32623          شير   14015  Noun             BODY
# 7    32624          شير   11682  Noun             FOOD
# 8    32625          شير   14011  Noun        SUBSTANCE
# 9    32626          شير   14008  Noun         ARTIFACT
# 10   32627          شير   14009  Noun           ANIMAL
# 11   32628          شير   14010  Noun         ARTIFACT
# 12  143856          شير   45276  Noun           OBJECT
#
#                                               example  \
# 0      غذاي اصلي کودکان تا 2 سالگي بايد شير مادر باشد
# 1                  --نامعلوم--:وارد برج اسد شده‌ايم *
# 2                شيران دلاور عرصه هاي نبرد حق بر باطل
# 3   او براي پيدا کردن شير همه ي داروخانه ها را زير...
# 4   آن شير را از روي قفسه بده تا براي بچه غذا درست...
# 5   کاپيتان تيم در ابتداي مسابقه شير را براي تعيين...
# 6   حيوانات اگر دچار سوتغذيه باشند از شير دادن به ...
# 7              --نامعلوم--:شير را گرم کن و بعد بخور *
# 8                       شيره ي درخت لباسش را کثيف کرد
# 9                                   شير توي يخچال است
# 10           --نامعلوم--:شير  به طرف گاوها حمله برد *
# 11                        شير آب  توي حياط يخ زده است
# 12  ويکي پديا:صورت فلکي اسد در فصل بهار در نيمکرة ...
#
#                                                 gloss
# 0   مايعي که از غده هاي پستاني انسان ماده ترشح مي ...
# 1   --نامعلوم--:برج پنجم از برج هاي دوازده گانه، پ...
# 2                           شخص شجاع ، دلاور و پهلوان
# 3   ماده اي خوراکي شامل شيري که آب آن را گرفته اند...
# 4                                   قوطي حاوي شير خشک
# 5   سمتي از سکه که اسکچ، نشان يا طرحي گرافيکي روي ...
# 6   مايعي خوراکي که از پستان  پستانداران ترشح مي ش...
# 7   --نامعلوم--:مايعي خوراکي که از گاو و گوسفند مي...
# 8    مايعي سفيد که در ساقه ي بعضي از گياهان وجود دارد
# 9                 قوطي يا بطري حاوي شير گاو يا گوسفند
# 10  --نامعلوم--:جانور پستاندار گوشت خوار بزرگ از گ...
# 11  هر وسيله اي که با بستن و باز کردن دهانه يا دري...
# 12  ويکي پديا:نام يکي از صورت‌هاي فلکي منطقةالبروج...

# %%
all_senses = fars_graph.get_all_senses_for_all_words()

# %%
grouped = all_senses.groupby('search_value').size().reset_index(name='frequency')
all_senses = all_senses.merge(grouped, on='search_value')
all_senses = all_senses.sort_values('frequency', ascending=False)
all_senses = all_senses.drop_duplicates('search_value')
all_senses = all_senses[all_senses['frequency'] > 5]
display(all_senses)
words = all_senses['search_value'].tolist()
print(words)
# Out:
#             id search_value  synset   pos semanticCategory  \
# 35811    30203           خط   12337  Noun            SHAPE
# 16144    49975      برداشتن   18239  Verb           change
# 52017    25615           سر   11887  Noun         LOCATION
# 108094  143691        گرفتن   45211  Noun              ACT
# 29219    29292           جا   11879  Noun         LOCATION
# ...        ...          ...     ...   ...              ...
# 28025    61936        توليد   26381  Noun         ARTIFACT
# 29465    24921          جام   14468  Noun         ARTIFACT
# 76069    34526         مجلس   13467  Noun         ARTIFACT
# 28776    61076        تکرار   10638  Noun              ACT
# 65438    33431        عنوان   12471  Noun            STATE
#
#                                                   example  \
# 35811                     --نامعلوم--:خط راست. خط منحني *
# 16144                   سنگيني وزنه ها را از من برداشتند.
# 52017   --نامعلوم--:کمباين فقط سر گندمها را مي چيد. عن...
# 108094  --ازخودم--:سلب‌کردن وي از مقامش بايد توسط مدير...
# 29219   او اشتباهاً جاي کس ديگري نشسته بود. ما جاههايم...
# ...                                                   ...
# 28025       بازده اين پروژه ي پزشکي يک داروي ضد سرطان است
# 29465              --نامعلوم--:کاسه اي پر از سوپ خوردم  *
# 76069                     معترضين جلوي پارلمان تجمع کردند
# 28776               دوره ي درسها, قبل از امتحان ضروري است
# 65438   --نامعلوم--:معروفيت او به خاطر کارهاي علمي‌اش ...
#
#                                                     gloss  frequency
# 35811   --نامعلوم--:شکلي که از به دنبال هم قرار گرفتن ...         28
# 16144                     جدا کردن و دور کردن چيزي از کسي         25
# 52017                    --نامعلوم--:بخش بالايي هر چيزي *         24
# 108094  --ساير--:کسي را از چيزي يا انجام کاري محروم يا...         23
# 29219   فضايي که براي نشستن( در تئاتر, قطار, هواپيماو ...         20
# ...                                                   ...        ...
# 28025         آنچه نتيجه ي توليد محصولي در حجم بالايي است          6
# 29465   --نامعلوم--:ظرف گود از جنس سفال يا چيني که در ...          6
# 76069   ساختمان يا سالني که هيئت نمايندگان مردم در آن ...          6
# 28776   مطالعه کردن مطلبي معمولاً به صورت تند و گذرا ج...          6
# 65438   --نامعلوم--:وضع يا کيفيت شناخته‌شدن توسط همه‌ي...          6
#
# [370 rows x 8 columns]
# ['خط', 'برداشتن', 'سر', 'گرفتن', 'جا', 'کشيدن', 'زدن', 'بار', 'کار', 'دست', 'دم', 'طرح', 'دوره', 'خوردن', 'بخش', 'راه', 'درجه', 'شير', 'پشت', 'بند', 'زبان', 'اب', 'چيز', 'ارام', 'دسته', 'انداختن', 'رسيدن', 'اثر', 'دنيا', 'سرويس', 'جز', 'گاز', 'ارتباط', 'پذيرفتن', 'رشته', 'ميدان', 'گذشتن', 'کرم', 'گل', 'جهان', 'نگهداشتن', 'حساب', 'بستن', 'واحد', 'پريدن', 'برگرداندن', 'خواندن', 'خواستن', 'ميزان', 'ردکردن', 'نمونه', 'پايه', 'شانه', 'مهر', 'بازي', 'ساختن', 'جمعکردن', 'ايستادن', 'پيوند', 'دل', 'نتيجه', 'خانه', 'مغز', 'گروه', 'کندن', 'سال', 'فهميدن', 'مثبت', 'شکستن', 'ساعت', 'سهم', 'برپاکردن', 'سايه', 'کف', 'بردن', 'کنترل', 'انقلاب', 'دور', 'زندگي', 'بزرگ', 'صورت', 'پرده', 'گشتن', 'رفتن', 'زير', 'زمين', 'سرباز', 'زمان', 'تار', 'روز', 'خير', 'نظر', 'پا', 'صحنه', 'پست', 'حال', 'امر', 'شاهد', 'دين', 'سياست', 'رابطه', 'حاشيه', 'روي', 'ريال', 'رشد', 'حکم', 'صافکردن', 'قرار', 'جامعه', 'بهوجوداوردن', 'کارکردن', 'مستقيم', 'سبک', 'عالم', 'دليل', 'پاککردن', 'عشق', 'دستي', 'مرکز', 'سطح', 'ماده', 'موضوع', 'موقعيت', 'جمع', 'بودن', 'ترک', 'محل', 'کل', 'درهم', 'نيرو', 'جايگاه', 'گرده', 'اخر', 'اصل', 'نقطه', 'راست', 'جريان', 'عملکردن', 'عمل', 'دفتر', 'گذشته', 'سمت', 'خواباندن', 'تن', 'بازار', 'شکل', 'سوختن', 'قسمت', 'ماندن', 'طرف', 'ادم', 'کمک', 'جداکردن', 'اوردن', 'شتري', 'نسبت', 'راي', 'رسيدگي', 'صدا', 'جداشدن', 'رسيدگيکردن', 'نوشتن', 'جان', 'نشستن', 'جهت', 'جابهجايي', 'فضا', 'نفتي', 'حامي', 'نماينده', 'نقش', 'شماره', 'گذراندن', 'پدر', 'جمعشدن', 'اهنگ', 'اول', 'شيري', 'حد', 'شيلينگ', 'چين', 'باز', 'ابشدن', 'انتقالدادن', 'مقام', 'اصلاحکردن', 'خراب', 'درستکردن', 'تند', 'تبديل', 'عامل', 'توان', 'ترکيب', 'عطف', 'پزو', 'قانون', 'سير', 'رو', 'بسته', 'ضعيف', 'هييت', 'ميل', 'تاريخ', 'سلام', 'پول', 'دادن', 'دارايي', 'برنامه', 'ساده', 'کره', 'برخورد', 'خوب', 'در', 'شاسي', 'صفحه', 'بازکردن', 'محور', 'انجامدادن', 'منبع', 'دينار', 'صرف', 'حق', 'سالم', 'تير', 'خاک', 'خاليکردن', 'گيره', 'خان', 'خارجکردن', 'بعد', 'سرمايه', 'دال', 'دستگاه', 'پيش', 'مورد', 'ساختار', 'جلودار', 'ملک', 'لب', 'بد', 'منطقه', 'دفاع', 'اطلاعات', 'درککردن', 'شور', 'چک', 'اعتبار', 'گرد', 'راهانداختن', 'درخشيدن', 'گرم', 'ستاره', 'بادي', 'منفي', 'چاپ', 'بالارفتن', 'پيچيدن', 'کشتي', 'نهاد', 'دستور', 'کليد', 'خمار', 'دنبالکردن', 'سکو', 'مسير', 'نظام', 'پرداختن', 'شرکت', 'خرابکردن', 'اينده', 'فکرکردن', 'چنگال', 'مسيله', 'خاکي', 'سيستم', 'بستهشدن', 'فصل', 'خبر', 'ارتفاع', 'نشان', 'چهره', 'کپيکردن', 'بنيان', 'نرم', 'شب', 'حفظکردن', 'حمله', 'ازبينرفتن', 'حمل', 'بنياد', 'نشاندن', 'بررسيکردن', 'برد', 'پخشکردن', 'نقل', 'شناسايي', 'ماه', 'سنگين', 'خوابيدن', 'چرخيدن', 'پي', 'نمايش', 'خوبي', 'سو', 'کوته', 'برگشتن', 'قدر', 'قدرت', 'خرد', 'فشار', 'قبولکردن', 'سوزاندن', 'خطا', 'ناراحت', 'خزانه', 'کوتاه', 'انتها', 'وقت', 'ابتدا', 'علم', 'واگذارکردن', 'مدعي', 'اندازه', 'رديف', 'محيط', 'کانال', 'توجه', 'رويه', 'انباشتن', 'ريختن', 'رييس', 'ثابت', 'روپيه', 'گسترشدادن', 'انسان', 'تور', 'صندوق', 'تصوير', 'وجه', 'ترتيب', 'تيغ', 'رد', 'عمر', 'کانون', 'هدايت', 'طول', 'جاانداختن', 'ولکردن', 'اجراکردن', 'ظرفيت', 'محکم', 'صاف', 'جدي', 'هوا', 'عصر', 'تمامکردن', 'جذب', 'اتش', 'جدول', 'متوجهشدن', 'علاقه', 'کاهش', 'انگاره', 'مرد', 'روشنکردن', 'توليد', 'جام', 'مجلس', 'تکرار', 'عنوان']

# %%
# save all values in search_value column as a csv file
words = all_senses['search_value']
words.to_csv('words.csv', index=False, header=False)

# %%
# Identify synsets with multiple senses
multiple_senses = fars_graph.synsets_with_multiple_senses()
display(multiple_senses)
# Out:
#         synset  sense_count
# 0          NaN         7208
# 1          1.0            4
# 2          2.0            2
# 3          4.0            2
# 4          5.0            9
# ...        ...          ...
# 25169  51715.0            2
# 25170  51716.0            3
# 25171  51718.0            3
# 25172  51721.0            2
# 25173  51722.0            2
#
# [25174 rows x 2 columns]

# %%
all_synsets_for_all_words = fars_graph.get_all_synsets_for_all_words()
display(all_synsets_for_all_words)

# %%
# Retrieve words with their most common sense
common_sense_words = fars_graph.words_with_most_common_sense()
display(common_sense_words)

# Sort by frequency in descending order
sorted_common_sense_words = common_sense_words.sort_values(by='frequency', ascending=False)
display(sorted_common_sense_words)
# Out:
# /tmp/ipykernel_27743/3610520101.py:168: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby('word').apply(lambda x: x.nlargest(1, 'frequency')).reset_index(drop=True)
#                     word   synset  frequency
# 0      "تغييريافتندرحجم"   7732.0          1
# 1          "خلقکردنذهني"   9267.0          1
# 2                   (ره)  45149.0          1
# 3                    (س)  45143.0          1
# 4                    (ص)  45153.0          1
# ...                  ...      ...        ...
# 97216              گچکار  23477.0          1
# 97217             گچکاري  23478.0          1
# 97218         گچکاريکردن   8954.0          1
# 97219            گچکشيدن   8954.0          1
# 97220            گچگرفتن  43267.0          1
#
# [97221 rows x 3 columns]
#                word   synset  frequency
# 81957         وراثت  19159.0          2
# 39915   رفتوامدکردن  21997.0          2
# 42197          رويي    307.0          2
# 42876        زاييدن   9432.0          2
# 42198        روييدن   8642.0          2
# ...             ...      ...        ...
# 29691         حيرون      NaN          0
# 29692        حيروني      NaN          0
# 76499      نسخهويرا      NaN          0
# 76500     نسخهپرداز      NaN          0
# 47234  سفرهخونهسنتي      NaN          0
#
# [97221 rows x 3 columns]

# %%
# List synsets and their corresponding lexicon information
synsets_lexicon = fars_graph.synsets_with_lexicon_info()
display(synsets_lexicon)
# Out:
#            id        pos semanticCategory  \
# 0       41115  Adjective         material
# 1         418  Adjective         material
# 2       25976  Adjective           social
# 3         931  Adjective             body
# 4         188  Adjective             body
# ...       ...        ...              ...
# 110086   8180       Verb      competition
# 110087  29914       Noun           PERSON
# 110088  11806       Noun            GROUP
# 110089  51721       Noun         LOCATION
# 110090  51722       Noun         LOCATION
#
#                                                   example  \
# 0       --ازخودم--:پتوي آب‌ديده * --ازخودم--:ديوار نم‌...
# 1                                           تخم مرغ آب پز
# 2       --نامعلوم--:خانواده هاي آبرومند اگر دچار مشکل ...
# 3                                            جانوران آبزي
# 4                زن باردار به بيمارستان رفت و وضع حمل کرد
# ...                                                   ...
# 110086      --نامعلوم--:ما در اين نبرد پيروز خواهيم شد. *
# 110087  --نامعلوم--:دندانپزشک عمومي که موفق به گذراندن...
# 110088  --نامعلوم--:هيئت‌منصفه به مجرم بودن متهم رأي د...
# 110089  ويکي پديا:آذربايجان غربي و شهرستان اروميه قطب ...
# 110090  ويکي پديا:نيک شهر از نظر جمعيتي در حد متوسط قر...
#
#                                                     gloss search_value
# 0       عميد:ويژگي آن‌چه در آب افتاده و يا آب به خود ک...       ابديده
# 1               ويژگي آنچه در آب و بدون روغن پخته شده است         ابپز
# 2       --نامعلوم--:آن که با آبرو زندگي مي کند و در نز...      ابرومند
# 3                      ويژگي موجودي که در آب زندگي مي کند         ابزي
# 4            ويژگي پستان دار ماده که در رحم خود جنين دارد        ابستن
# ...                                                   ...          ...
# 110086  --نامعلوم--:غلبه کردن بر دشمن در جنگ و شکست دا...     شکستدادن
# 110087  --نامعلوم--:دندانپزشک متخصصي است که وظيفه تشخي...      لثهپزشک
# 110088  --نامعلوم--:جمعي از صاحبان رشته‌ها و طبقات شغل...     هييتژوري
# 110089  --ازخودم--:يکي از شهرستان‌هاي استان آذربايجان ...       اروميه
# 110090  ويکي پديا:نيک‌شَهر يکي از شهرهاي استان سيستان ...       نيکشهر
#
# [110091 rows x 6 columns]

# %%
# Extract senses and their synsets for a particular part of speech
senses_pos = fars_graph.senses_by_pos('Noun')
display(senses_pos)
# Out:
#            id  synset   pos search_value
# 0       24585   10054  Noun   1000000000
# 1       24586   12632  Noun       24ساعت
# 2       24587   12634  Noun       24ساعت
# 3       24588   12653  Noun       365روز
# 4       24589   12666  Noun      60دقيقه
# ...       ...     ...   ...          ...
# 64758  167806   50264  Noun     رکوردزني
# 64759  167809   29914  Noun      لثهپزشک
# 64760  167810   11806  Noun     هييتژوري
# 64761  167811   51721  Noun       اروميه
# 64762  167812   51722  Noun       نيکشهر
#
# [64763 rows x 4 columns]

# %%
# Determine the distribution of senses across different parts of speech
senses_distribution = fars_graph.senses_distribution()
display(senses_distribution)
# Out:
#          pos  sense_count
# 0  Adjective        17648
# 1     Adverb         4693
# 2       Noun        64763
# 3       Verb        22987

# %%
# Identify unique senses for a given semantic category
unique_senses_category = fars_graph.unique_senses_by_semantic_category('material')
display(unique_senses_category)
# Out:
#           id  synset search_value
# 0      13841   41115       ابديده
# 1      13842     418         ابپز
# 2      13847    1146         ابکي
# 3      13848     235          ابي
# 4      13851     202          ابي
# ...      ...     ...          ...
# 1816  167504    1306        بيرمق
# 1817  167507   51617        رژلبي
# 1818  167508   51617       ماتيکي
# 1819  167546   51648   بههمپيچيده
# 1820  167643   47676     دلمهبسته
#
# [1821 rows x 3 columns]

# %%
# Retrieve examples for synsets with a specific gloss pattern
gloss_pattern = fars_graph.synsets_with_gloss_pattern('نامعلوم')
display(gloss_pattern)
# Out:
#           id                                            example  \
# 0          1                         --ازخودم--:سيم‌کشي روکار *
# 1          2  --نامعلوم--:سيم‌کشي توکار * وب: سيستم لوله‌کشي...
# 2          5  --نامعلوم--:انسان معمولا با دوستان صميمي درددل...
# 3          6  --نامعلوم--:با رفتار سرد و بي احساسش همه را پک...
# 4          7  --نامعلوم--:کارهايتان را زمان ديرتري انجام دهيد *
# ...      ...                                                ...
# 11482  51304  --نامعلوم--:پاراگلايدر يک وسيله پرنده تفريحي ا...
# 11483  51341  --ازخودم--:گاو حيواني نشخوارکننده است. * --نام...
# 11484  51489  --نامعلوم--:جمهوري از روياهايي بعضي از فيلسوفا...
# 11485  51714  --نامعلوم--:عکس هاي جشن نامزدي بعد از رتوش بسي...
# 11486  51715  --نامعلوم--:زمين‌هاي آنجا بيشتر تپه‌ماهور است ...
#
#                                                    gloss
# 0         --نامعلوم--:مربوط به سطح بيروني يا رويي چيزي *
# 1          --نامعلوم--:مربوط به داخل يا سطح زيرين چيزي *
# 2              --نامعلوم--:داراي رابطه نزديک و صميمانه *
# 3                         --نامعلوم--:بدون احساس و شور *
# 4      --نامعلوم--:واقع در زماني پس از زمان مناسب يا ...
# ...                                                  ...
# 11482  --نامعلوم--:وسيله‌اي که قادر به پرواز است. * -...
# 11483  --نامعلوم--:گروهي از چهارپايان که معدة چهارقسم...
# 11484  --نامعلوم--:حکومتي که فردي در آن از طرف مردم و...
# 11485  --نامعلوم--:دست کاري و اصلاح کردن عکس پس از ظه...
# 11486  --نامعلوم--:زمين ناهموار و پر از پستي‌وبلندي *...
#
# [11487 rows x 3 columns]

# %%
# Find synsets with no direct mapping and their glosses
no_mapping_synsets = fars_graph.synsets_with_no_mapping()
display(no_mapping_synsets)
# Out:
#           id                                              gloss
# 0        166  --نامعلوم--:ويژگي بليطي که براي دو سفر رفت و ب...
# 1        203  ويژگي زراعتي که با آب باران نمو کند و آن را آب...
# 2        233  ويژگي صفحه عکاسي اي که ظاهر و ثابت شده و درآن ...
# 3        283                          ويژگي يکي از قطع هاي کتاب
# 4        320                      قرار گرفته در قسمت بالايي بدن
# ...      ...                                                ...
# 11681  51718  --ازخودم--:ابهام زدايي از واژگان مبهم و داراي ...
# 11682  51719               سخن:خوردن مواد مقوي براي تقويت شدن *
# 11683  51720                          سخن:نوشتن يا نقاشي کردن *
# 11684  51721  --ازخودم--:يکي از شهرستان‌هاي استان آذربايجان ...
# 11685  51722  ويکي پديا:نيک‌شَهر يکي از شهرهاي استان سيستان ...
#
# [11686 rows x 2 columns]

# %%
# Identify unique senses for a given semantic category
unique_senses_category = fars_graph.unique_senses_by_semantic_category('body')
display(unique_senses_category)
# Out:
#           id  synset          search_value
# 0      13844     931                  ابزي
# 1      13845     188                 ابستن
# 2      13913     967                اميزشي
# 3      13933    1868                  ابتر
# 4      14004     906              استثنايي
# ...      ...     ...                   ...
# 2452  167711     948             براماسيده
# 2453  167712   33457               خونپالا
# 2454  167767   51692  ابزيرپوست[کسي]افتادن
# 2455  167803   51719             تقويتکردن
# 2456  167807   30490       تلنگ[کسي]دررفتن
#
# [2457 rows x 3 columns]

# %%
# Retrieve examples for synsets with a specific gloss pattern
gloss_pattern = fars_graph.synsets_with_gloss_pattern('ازخودم')
display(gloss_pattern)
# Out:
#          id                                            example  \
# 0        58  --نامعلوم--:پارچه سبز * --نامعلوم--:برگ هاي سبز *
# 1        93  --نامعلوم--:دوستم خوش‌بنيه است و  به ندرت مريض...
# 2       682  --نامعلوم--:قهرمان مغرور رقيب را جدي نگرفت و ش...
# 3       744  --نامعلوم--:او در شهر خود شخصيتي مطرود به شمار...
# 4      1709  --نامعلوم--:معدل بالاي او مويد تلاش خستگي‌ناپذ...
# ...     ...                                                ...
# 2868  51708  وب: ببين که يار نامهربان و کم لطف در اين عشق ب...
# 2869  51709  سخن:هم ز فرعون بهيمي دور شو / هم به ميغات آي و...
# 2870  51717  --ازخودم--:او با آرنج به من زد تا به او حالي ک...
# 2871  51718  --ازخودم--:براي رفع ابهام معنايي واژگان متن مو...
# 2872  51721  ويکي پديا:آذربايجان غربي و شهرستان اروميه قطب ...
#
#                                                   gloss
# 0       --ازخودم--:داراي رنگ سبز، رنگي ميان زرد و آبي *
# 1     --نامعلوم--:داراي قدرت جسماني بالا * --ازخودم-...
# 2     --ازخودم--:ويژگي آن‌که دچار غرور است و خود را ...
# 3     --ازخودم--:ويژگي آن‌که ديگران رهايش کرده يا او...
# 4     --ازخودم--:ويژگي کسي يا چيزي که صحت عملي و يا ...
# ...                                                 ...
# 2868                       --ازخودم--:فاقد مهر و محبت *
# 2869  --ازخودم--:ويژگي آن‌چه مربوط به حيوان است که ا...
# 2870                          --ازخودم--:به آرامي زدن *
# 2871  --ازخودم--:ابهام زدايي از واژگان مبهم و داراي ...
# 2872  --ازخودم--:يکي از شهرستان‌هاي استان آذربايجان ...
#
# [2873 rows x 3 columns]

# %%
# Find synsets with no direct mapping and their glosses
no_mapping_synsets = fars_graph.synsets_with_no_mapping()
display(no_mapping_synsets)
# Out:
#           id                                              gloss
# 0        166  --نامعلوم--:ويژگي بليطي که براي دو سفر رفت و ب...
# 1        203  ويژگي زراعتي که با آب باران نمو کند و آن را آب...
# 2        233  ويژگي صفحه عکاسي اي که ظاهر و ثابت شده و درآن ...
# 3        283                          ويژگي يکي از قطع هاي کتاب
# 4        320                      قرار گرفته در قسمت بالايي بدن
# ...      ...                                                ...
# 11681  51718  --ازخودم--:ابهام زدايي از واژگان مبهم و داراي ...
# 11682  51719               سخن:خوردن مواد مقوي براي تقويت شدن *
# 11683  51720                          سخن:نوشتن يا نقاشي کردن *
# 11684  51721  --ازخودم--:يکي از شهرستان‌هاي استان آذربايجان ...
# 11685  51722  ويکي پديا:نيک‌شَهر يکي از شهرهاي استان سيستان ...
#
# [11686 rows x 2 columns]
